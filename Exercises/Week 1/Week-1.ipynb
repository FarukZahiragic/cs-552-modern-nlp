# %% [markdown]
# # 📚 Exercise Session - Week 1
#
# Welcome to Week 1 exercise session of **CS-552: Modern NLP**!
#
# > **What will be covered:**
# > 1. [**TASK A:** Training a word embedding model](#1)
# > 2. [**TASK B:** Word embedding similarity](#2)
# > 3. [**TASK C:** Sentiment analysis of movie reviews](#3)
#
# > **By the end of the session you will be able to:**
# > - ✅  train from scratch a word embedding model
# > - ✅  load and use pre-trained word embeddings
# > - ✅  perform word embedding analogies and understand their implicit biases
# > - ✅  train and evaluate a sentiment classifier using word embeddings

# %% [markdown]
# ## Intro - Word embedding models
#
# #### 🔵 What?
# A word embedding is a learned representation for text where words that have the same meaning have a similar representation. It is this approach to representing words and documents that may be considered one of the key breakthroughs of deep learning on challenging natural language processing problems.
#
#
# #### 🟡 How?
# There are different versions of word embeddings depending on the way the embeddings are learned.
# - Some of the models learn a focus word given the neighboring words that surround them
# - Some other models learn the neighboring words given the focus word.
# - Some other word embedding models try to derive the relationship between the words from global statistics of the words in the overall corpus.
#
#
# #### 🟣 Why?
# Word embedding in NLP is an important concept that is used for representing words for text analysis in the form of real-valued vectors. It is an advancement in NLP that has improved the ability of computers to understand text-based content in a better way.
#
#
# #### A little bit of history on word embeddings
# In 2013, Tomas Mikolov et al. developed an algorithm for learning word embeddings called **Word2vec** [[paper](https://arxiv.org/abs/1301.3781)][[code](https://code.google.com/archive/p/word2vec/)]. This algorithm uses a shallow neural network to learn word vectors so that the representation of each word of a given corpus is good at predicting its own contexts (Skip-Gram) or vice versa (CBOW).
#
# One year after the publication of Word2vec, Pennington et al. developed a new algorithm for learning word embeddings called **GloVe** [[paper](https://nlp.stanford.edu/pubs/glove.pdf)][[code](https://github.com/stanfordnlp/GloVe)]. This algorithm is based on the observation that word relationships can be recovered from the co-occurrence statistics of any (large enough) corpus.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid orange;background-color:#F3F3F3;color:#424242;">
#     <h3>Goal of today's exercise</h3><br/>
# In this exercise session, we will use both variants of these word embedding models (Word2Vec and GloVe) for our experiments.
# For the first part, we will train from scratch a Word2vec model with different datasets. In the second part, we will load pre-trained Word2vec and GloVe embeddings and test them on how well they capture concept similarity among words. Finally, for the last part, we will train a simple sentiment analysis classifier with these pre-trained embeddings as we discussed in the lecture.
#
# You will need to fill in all the missing pieces of code. For each one, you will be given a 🎯 `Goal` guidance that explains the steps you need to implement and a 💻 `API` reference with the functions or classes you can use to achieve each goal.
#
# </div>

# %%
# !conda create -n "mnlp_exercises" python=3.10.11 --yes
# Out:
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/fzahiragic/miniconda3/envs/mnlp_exercises
#
#   added / updated specs:
#     - python=3.10.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ld_impl_linux-64-2.44      |       h9e0c5a2_3         725 KB
#     openssl-3.5.5              |       h1b28b03_0         5.5 MB
#     sqlite-3.51.1              |       h3e8d24a_1         1.2 MB
#     tzdata-2026a               |       he532380_0         117 KB
#     xz-5.8.2                   |       h448239c_0         621 KB
#     ------------------------------------------------------------
#                                            Total:         8.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.12.2-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_7
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_7
#   libgomp            pkgs/main/linux-64::libgomp-15.2.0-h4751f2c_7
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_7
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_7
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.5-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-25.0-py310h06a4308_1
#   pip                pkgs/main/noarch::pip-26.0.1-pyhc872135_0
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.10.11-h955ad1f_3
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-80.10.2-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.51.1-h3e8d24a_1
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026a-he532380_0
#   wheel              pkgs/main/linux-64::wheel-0.46.3-py310h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.1-hb25bd0a_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.5.5        | 5.5 MB    |                                       |   0%
# sqlite-3.51.1        | 1.2 MB    |                                       |   0%
#
# ld_impl_linux-64-2.4 | 725 KB    |                                       |   0%
#
#
# xz-5.8.2             | 621 KB    |                                       |   0%
#
#
#
# tzdata-2026a         | 117 KB    |                                       |   0%
#
#
#
# tzdata-2026a         | 117 KB    | #####                                 |  14%
#
#
#
# tzdata-2026a         | 117 KB    | ##################################### | 100%
# sqlite-3.51.1        | 1.2 MB    | 4                                     |   1%
#
# ld_impl_linux-64-2.4 | 725 KB    | 8                                     |   2%
#
#
# openssl-3.5.5        | 5.5 MB    | 1                                     |   0%
#
# ld_impl_linux-64-2.4 | 725 KB    | ##########6                           |  29%
# sqlite-3.51.1        | 1.2 MB    | #####7                                |  16%
#
#
# openssl-3.5.5        | 5.5 MB    | 5                                     |   1%
# sqlite-3.51.1        | 1.2 MB    | ###########5                          |  31%
#
#
# xz-5.8.2             | 621 KB    | ####################9                 |  57%
#
# openssl-3.5.5        | 5.5 MB    | #6                                    |   5%
# sqlite-3.51.1        | 1.2 MB    | #################2                    |  47%
#
# ld_impl_linux-64-2.4 | 725 KB    | ################################6     |  88%
#
#
# xz-5.8.2             | 621 KB    | ############################6         |  77%
#
# ld_impl_linux-64-2.4 | 725 KB    | ##################################### | 100%
# openssl-3.5.5        | 5.5 MB    | ##5                                   |   7%
#
#
# xz-5.8.2             | 621 KB    | ####################################2 |  98%
#
#
# xz-5.8.2             | 621 KB    | ##################################### | 100%
# openssl-3.5.5        | 5.5 MB    | ####                                  |  11%
# openssl-3.5.5        | 5.5 MB    | #####9                                |  16%
#
# openssl-3.5.5        | 5.5 MB    | ###########9                          |  32%
# sqlite-3.51.1        | 1.2 MB    | ##################################### | 100%
#
#
#
# openssl-3.5.5        | 5.5 MB    | ##############3                       |  39%
#
#
#
# openssl-3.5.5        | 5.5 MB    | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate mnlp_exercises
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda activate mnlp_exercises
# Out:
# CondaError: Run 'conda init' before 'conda activate'

# %%
# !pip install pandas gensim numpy matplotlib seaborn scikit-learn tqdm torch torchmetrics ipykernel
# Out:
# Requirement already satisfied: pandas in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: gensim in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (4.4.0)
# Requirement already satisfied: numpy in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (2.2.5)
# Requirement already satisfied: matplotlib in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: seaborn in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: tqdm in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: torch in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (2.10.0)
# Requirement already satisfied: torchmetrics in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (1.8.2)
# Requirement already satisfied: ipykernel in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (6.29.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.7.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from gensim) (1.16.2)
# Requirement already satisfied: smart_open>=1.8.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from gensim) (7.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: joblib>=1.3.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: filelock in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (73.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from cuda-bindings==12.9.4->torch) (1.4.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: comm>=0.1.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (9.1.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: wrapt in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure_eval in /home/fzahiragic/miniconda3/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
# imported libraries for this exercise
import pandas as pd
import numpy as np
from gensim.test.utils import common_texts
from gensim.utils import tokenize   
from gensim.models import Word2Vec
import gensim.downloader
import torch 
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchmetrics.classification import BinaryAccuracy
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# <a name="1"></a>
# ## 1. TASK A: Training a word embedding model from stratch
#
# In this part, you will train a model to learn vector representations of words and more specifically, we will train the word2vec model.
# To train the model we will use the Gensim library which is a free open-source Python library for representing documents as semantic vectors.
#
# > **Gensim** is designed to process raw, unstructured digital texts (“plain text”) using unsupervised machine learning algorithms. The algorithms in Gensim, such as Word2Vec, FastText, Latent Semantic Indexing (LSI, LSA, LsiModel), Latent Dirichlet Allocation (LDA, LdaModel) etc, automatically discover the semantic structure of documents by examining statistical co-occurrence patterns within a corpus of training documents. These algorithms are unsupervised, which means no human input is necessary – you only need a corpus of plain text documents.
# >
# > You can discover all Gensim functionalities [here](https://radimrehurek.com/gensim/index.html).
#
# To train your embedding model, you will need to instantiate Word2Vec and pass the data to the model to train with. We essentially need to pass on a list of lists, where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary.
#
# **Data:** We will train our embedding model using a toy dataset that is provided by the Gensim library. You can use the dataset under the following path `gensim.test.utils.common_texts`.

# %%
# bag of words for each sentence in toy dataset (imported from the gensim library in cell 2)
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %% [markdown]
# #### Train a Gensim Word2Vec model

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Train with `common_texts` dataset a Gensim word2vec model.<br>
#
# - 💻  **API:** You can use `gensim.models.Word2Vec` class.
# </div>

# %%
from gensim import downloader as api

tokens = api.load('text8')
sentences = list(tokens)

# %%
#instantiate and train model
w2v_model = gensim.models.Word2Vec(vector_size=10, window=5, min_count=1, workers=4)
w2v_model.build_vocab(sentences)
w2v_model.train(sentences, total_examples=len(sentences), epochs=10)
# Out:
# (128194472, 170052070)

# %%
# dict with vocabulary key indexes
words = w2v_model.wv.key_to_index
words
# Out:
# {'the': 0,
#  'of': 1,
#  'and': 2,
#  'one': 3,
#  'in': 4,
#  'a': 5,
#  'to': 6,
#  'zero': 7,
#  'nine': 8,
#  'two': 9,
#  'is': 10,
#  'as': 11,
#  'eight': 12,
#  'for': 13,
#  's': 14,
#  'five': 15,
#  'three': 16,
#  'was': 17,
#  'by': 18,
#  'that': 19,
#  'four': 20,
#  'six': 21,
#  'seven': 22,
#  'with': 23,
#  'on': 24,
#  'are': 25,
#  'it': 26,
#  'from': 27,
#  'or': 28,
#  'his': 29,
#  'an': 30,
#  'be': 31,
#  'this': 32,
#  'which': 33,
#  'at': 34,
#  'he': 35,
#  'also': 36,
#  'not': 37,
#  'have': 38,
#  'were': 39,
#  'has': 40,
#  'but': 41,
#  'other': 42,
#  'their': 43,
#  'its': 44,
#  'first': 45,
#  'they': 46,
#  'some': 47,
#  'had': 48,
#  'all': 49,
#  'more': 50,
#  'most': 51,
#  'can': 52,
#  'been': 53,
#  'such': 54,
#  'many': 55,
#  'who': 56,
#  'new': 57,
#  'used': 58,
#  'there': 59,
#  'after': 60,
#  'when': 61,
#  'into': 62,
#  'american': 63,
#  'time': 64,
#  'these': 65,
#  'only': 66,
#  'see': 67,
#  'may': 68,
#  'than': 69,
#  'world': 70,
#  'i': 71,
#  'b': 72,
#  'would': 73,
#  'd': 74,
#  'no': 75,
#  'however': 76,
#  'between': 77,
#  'about': 78,
#  'over': 79,
#  'years': 80,
#  'states': 81,
#  'people': 82,
#  'war': 83,
#  'during': 84,
#  'united': 85,
#  'known': 86,
#  'if': 87,
#  'called': 88,
#  'use': 89,
#  'th': 90,
#  'system': 91,
#  'often': 92,
#  'state': 93,
#  'so': 94,
#  'history': 95,
#  'will': 96,
#  'up': 97,
#  'while': 98,
#  'where': 99,
#  'city': 100,
#  'being': 101,
#  'english': 102,
#  'then': 103,
#  'any': 104,
#  'both': 105,
#  'under': 106,
#  'out': 107,
#  'made': 108,
#  'well': 109,
#  'her': 110,
#  'e': 111,
#  'number': 112,
#  'government': 113,
#  'them': 114,
#  'm': 115,
#  'later': 116,
#  'since': 117,
#  'him': 118,
#  'part': 119,
#  'name': 120,
#  'c': 121,
#  'century': 122,
#  'through': 123,
#  'because': 124,
#  'x': 125,
#  'university': 126,
#  'early': 127,
#  'life': 128,
#  'british': 129,
#  'year': 130,
#  'like': 131,
#  'same': 132,
#  'including': 133,
#  'became': 134,
#  'example': 135,
#  'day': 136,
#  'each': 137,
#  'even': 138,
#  'work': 139,
#  'language': 140,
#  'although': 141,
#  'several': 142,
#  'form': 143,
#  'john': 144,
#  'u': 145,
#  'national': 146,
#  'very': 147,
#  'much': 148,
#  'g': 149,
#  'french': 150,
#  'before': 151,
#  'general': 152,
#  'what': 153,
#  't': 154,
#  'against': 155,
#  'n': 156,
#  'high': 157,
#  'links': 158,
#  'could': 159,
#  'based': 160,
#  'those': 161,
#  'now': 162,
#  'second': 163,
#  'de': 164,
#  'music': 165,
#  'another': 166,
#  'large': 167,
#  'she': 168,
#  'f': 169,
#  'external': 170,
#  'german': 171,
#  'different': 172,
#  'modern': 173,
#  'great': 174,
#  'do': 175,
#  'common': 176,
#  'set': 177,
#  'list': 178,
#  'south': 179,
#  'series': 180,
#  'major': 181,
#  'game': 182,
#  'power': 183,
#  'long': 184,
#  'country': 185,
#  'king': 186,
#  'law': 187,
#  'group': 188,
#  'film': 189,
#  'still': 190,
#  'until': 191,
#  'north': 192,
#  'international': 193,
#  'term': 194,
#  'we': 195,
#  'end': 196,
#  'book': 197,
#  'found': 198,
#  'own': 199,
#  'political': 200,
#  'party': 201,
#  'order': 202,
#  'usually': 203,
#  'president': 204,
#  'church': 205,
#  'you': 206,
#  'death': 207,
#  'theory': 208,
#  'area': 209,
#  'around': 210,
#  'include': 211,
#  'god': 212,
#  'ii': 213,
#  'way': 214,
#  'did': 215,
#  'military': 216,
#  'population': 217,
#  'using': 218,
#  'though': 219,
#  'small': 220,
#  'following': 221,
#  'within': 222,
#  'non': 223,
#  'left': 224,
#  'human': 225,
#  'main': 226,
#  'among': 227,
#  'point': 228,
#  'r': 229,
#  'due': 230,
#  'p': 231,
#  'considered': 232,
#  'public': 233,
#  'popular': 234,
#  'computer': 235,
#  'west': 236,
#  'family': 237,
#  'east': 238,
#  'information': 239,
#  'important': 240,
#  'european': 241,
#  'man': 242,
#  'sometimes': 243,
#  'right': 244,
#  'old': 245,
#  'free': 246,
#  'word': 247,
#  'without': 248,
#  'last': 249,
#  'us': 250,
#  'members': 251,
#  'given': 252,
#  'times': 253,
#  'roman': 254,
#  'make': 255,
#  'h': 256,
#  'age': 257,
#  'place': 258,
#  'l': 259,
#  'thus': 260,
#  'science': 261,
#  'case': 262,
#  'become': 263,
#  'systems': 264,
#  'union': 265,
#  'born': 266,
#  'york': 267,
#  'line': 268,
#  'countries': 269,
#  'does': 270,
#  'isbn': 271,
#  'st': 272,
#  'control': 273,
#  'various': 274,
#  'others': 275,
#  'house': 276,
#  'article': 277,
#  'island': 278,
#  'should': 279,
#  'led': 280,
#  'back': 281,
#  'period': 282,
#  'player': 283,
#  'europe': 284,
#  'languages': 285,
#  'central': 286,
#  'water': 287,
#  'few': 288,
#  'western': 289,
#  'home': 290,
#  'began': 291,
#  'generally': 292,
#  'less': 293,
#  'k': 294,
#  'similar': 295,
#  'written': 296,
#  'original': 297,
#  'best': 298,
#  'must': 299,
#  'according': 300,
#  'school': 301,
#  'france': 302,
#  'air': 303,
#  'single': 304,
#  'force': 305,
#  'v': 306,
#  'land': 307,
#  'groups': 308,
#  'down': 309,
#  'how': 310,
#  'works': 311,
#  'development': 312,
#  'official': 313,
#  'support': 314,
#  'england': 315,
#  'j': 316,
#  'rather': 317,
#  'space': 318,
#  'data': 319,
#  'greek': 320,
#  'km': 321,
#  'named': 322,
#  'germany': 323,
#  'just': 324,
#  'games': 325,
#  'said': 326,
#  'version': 327,
#  'late': 328,
#  'earth': 329,
#  'company': 330,
#  'every': 331,
#  'economic': 332,
#  'short': 333,
#  'published': 334,
#  'black': 335,
#  'army': 336,
#  'off': 337,
#  'london': 338,
#  'million': 339,
#  'body': 340,
#  'field': 341,
#  'christian': 342,
#  'either': 343,
#  'empire': 344,
#  'social': 345,
#  'o': 346,
#  'developed': 347,
#  'standard': 348,
#  'court': 349,
#  'service': 350,
#  'kingdom': 351,
#  'along': 352,
#  'college': 353,
#  'republic': 354,
#  'sea': 355,
#  'america': 356,
#  'today': 357,
#  'result': 358,
#  'held': 359,
#  'team': 360,
#  'light': 361,
#  'means': 362,
#  'never': 363,
#  'especially': 364,
#  'third': 365,
#  'further': 366,
#  'forces': 367,
#  'character': 368,
#  'take': 369,
#  'men': 370,
#  'society': 371,
#  'show': 372,
#  'open': 373,
#  'possible': 374,
#  'fact': 375,
#  'battle': 376,
#  'took': 377,
#  'former': 378,
#  'books': 379,
#  'soviet': 380,
#  'river': 381,
#  'children': 382,
#  'having': 383,
#  'good': 384,
#  'local': 385,
#  'son': 386,
#  'current': 387,
#  'process': 388,
#  'natural': 389,
#  'present': 390,
#  'himself': 391,
#  'islands': 392,
#  'total': 393,
#  'near': 394,
#  'white': 395,
#  'days': 396,
#  'person': 397,
#  'itself': 398,
#  'seen': 399,
#  'culture': 400,
#  'little': 401,
#  'above': 402,
#  'software': 403,
#  'largest': 404,
#  'words': 405,
#  'upon': 406,
#  'level': 407,
#  'father': 408,
#  'side': 409,
#  'created': 410,
#  'red': 411,
#  'references': 412,
#  'press': 413,
#  'full': 414,
#  'region': 415,
#  'almost': 416,
#  'al': 417,
#  'image': 418,
#  'famous': 419,
#  'play': 420,
#  'came': 421,
#  'role': 422,
#  'once': 423,
#  'certain': 424,
#  'league': 425,
#  'jewish': 426,
#  'james': 427,
#  'january': 428,
#  'site': 429,
#  'again': 430,
#  'art': 431,
#  'numbers': 432,
#  'member': 433,
#  'areas': 434,
#  'movement': 435,
#  'type': 436,
#  'religious': 437,
#  'march': 438,
#  'community': 439,
#  'story': 440,
#  'played': 441,
#  'production': 442,
#  'released': 443,
#  'center': 444,
#  'rights': 445,
#  'real': 446,
#  'related': 447,
#  'foreign': 448,
#  'low': 449,
#  'ancient': 450,
#  'view': 451,
#  'terms': 452,
#  'source': 453,
#  'act': 454,
#  'minister': 455,
#  'change': 456,
#  'energy': 457,
#  'produced': 458,
#  'research': 459,
#  'actor': 460,
#  'making': 461,
#  'december': 462,
#  'civil': 463,
#  'women': 464,
#  'special': 465,
#  'style': 466,
#  'japanese': 467,
#  'design': 468,
#  'william': 469,
#  'available': 470,
#  'chinese': 471,
#  'forms': 472,
#  'canada': 473,
#  'northern': 474,
#  'died': 475,
#  'class': 476,
#  'living': 477,
#  'next': 478,
#  'particular': 479,
#  'program': 480,
#  'council': 481,
#  'television': 482,
#  'head': 483,
#  'david': 484,
#  'china': 485,
#  'middle': 486,
#  'established': 487,
#  'bc': 488,
#  'hand': 489,
#  'far': 490,
#  'july': 491,
#  'function': 492,
#  'position': 493,
#  'y': 494,
#  'built': 495,
#  'george': 496,
#  'band': 497,
#  'together': 498,
#  'w': 499,
#  'latin': 500,
#  'thought': 501,
#  'eastern': 502,
#  'charles': 503,
#  'parts': 504,
#  'instead': 505,
#  'study': 506,
#  'india': 507,
#  'might': 508,
#  'code': 509,
#  'meaning': 510,
#  'included': 511,
#  'trade': 512,
#  'per': 513,
#  'june': 514,
#  'least': 515,
#  'half': 516,
#  'model': 517,
#  'economy': 518,
#  'prime': 519,
#  'traditional': 520,
#  'always': 521,
#  'capital': 522,
#  'range': 523,
#  'emperor': 524,
#  'november': 525,
#  'young': 526,
#  'anti': 527,
#  'final': 528,
#  'text': 529,
#  'players': 530,
#  'uk': 531,
#  'april': 532,
#  'run': 533,
#  'september': 534,
#  'radio': 535,
#  'addition': 536,
#  'live': 537,
#  'august': 538,
#  'note': 539,
#  'taken': 540,
#  'italian': 541,
#  'lost': 542,
#  'nature': 543,
#  'project': 544,
#  'technology': 545,
#  'spanish': 546,
#  'october': 547,
#  'rate': 548,
#  'recent': 549,
#  'won': 550,
#  'true': 551,
#  'value': 552,
#  'uses': 553,
#  'russian': 554,
#  'est': 555,
#  'wrote': 556,
#  'effect': 557,
#  'album': 558,
#  'southern': 559,
#  'africa': 560,
#  'whose': 561,
#  'top': 562,
#  'historical': 563,
#  'australia': 564,
#  'catholic': 565,
#  'particularly': 566,
#  'self': 567,
#  'structure': 568,
#  'record': 569,
#  'evidence': 570,
#  'themselves': 571,
#  'rule': 572,
#  'influence': 573,
#  'cases': 574,
#  'subject': 575,
#  'referred': 576,
#  'continued': 577,
#  'nations': 578,
#  'rock': 579,
#  'below': 580,
#  'japan': 581,
#  'com': 582,
#  'song': 583,
#  'names': 584,
#  'throughout': 585,
#  'female': 586,
#  'title': 587,
#  'our': 588,
#  'therefore': 589,
#  'office': 590,
#  'star': 591,
#  'paul': 592,
#  'too': 593,
#  'cities': 594,
#  'independent': 595,
#  'february': 596,
#  'author': 597,
#  'problem': 598,
#  'species': 599,
#  'done': 600,
#  'education': 601,
#  'philosophy': 602,
#  'come': 603,
#  'higher': 604,
#  'originally': 605,
#  'market': 606,
#  'town': 607,
#  'my': 608,
#  'season': 609,
#  'love': 610,
#  'strong': 611,
#  'israel': 612,
#  'writer': 613,
#  'irish': 614,
#  'films': 615,
#  'elements': 616,
#  'robert': 617,
#  'whether': 618,
#  'despite': 619,
#  'eventually': 620,
#  'here': 621,
#  'football': 622,
#  'action': 623,
#  'internet': 624,
#  'sound': 625,
#  'individual': 626,
#  'network': 627,
#  'described': 628,
#  'practice': 629,
#  'characters': 630,
#  're': 631,
#  'royal': 632,
#  'la': 633,
#  'events': 634,
#  'formed': 635,
#  'commonly': 636,
#  'base': 637,
#  'received': 638,
#  'problems': 639,
#  'african': 640,
#  'food': 641,
#  'jews': 642,
#  'able': 643,
#  'male': 644,
#  'mass': 645,
#  'typically': 646,
#  'complex': 647,
#  'lower': 648,
#  'includes': 649,
#  'outside': 650,
#  'legal': 651,
#  'complete': 652,
#  'parliament': 653,
#  'significant': 654,
#  'actually': 655,
#  'business': 656,
#  'fiction': 657,
#  'physical': 658,
#  'followed': 659,
#  'deaths': 660,
#  'key': 661,
#  'widely': 662,
#  'leader': 663,
#  'page': 664,
#  'basic': 665,
#  'types': 666,
#  'henry': 667,
#  'beginning': 668,
#  'elected': 669,
#  'fire': 670,
#  'building': 671,
#  'independence': 672,
#  'went': 673,
#  'aircraft': 674,
#  'movie': 675,
#  'ever': 676,
#  'canadian': 677,
#  'material': 678,
#  'births': 679,
#  'video': 680,
#  'news': 681,
#  'future': 682,
#  'scientific': 683,
#  'simply': 684,
#  'go': 685,
#  'defined': 686,
#  'laws': 687,
#  'get': 688,
#  'close': 689,
#  'industry': 690,
#  'specific': 691,
#  'examples': 692,
#  'services': 693,
#  'believe': 694,
#  'idea': 695,
#  'introduced': 696,
#  'method': 697,
#  'points': 698,
#  'return': 699,
#  'cause': 700,
#  'indian': 701,
#  'britain': 702,
#  'features': 703,
#  'size': 704,
#  'majority': 705,
#  'post': 706,
#  'lead': 707,
#  'organization': 708,
#  'cannot': 709,
#  'designed': 710,
#  'ireland': 711,
#  'cross': 712,
#  'classical': 713,
#  'personal': 714,
#  'writing': 715,
#  'concept': 716,
#  'required': 717,
#  'associated': 718,
#  'soon': 719,
#  'changes': 720,
#  'located': 721,
#  'california': 722,
#  'sense': 723,
#  'believed': 724,
#  'started': 725,
#  'away': 726,
#  'co': 727,
#  'religion': 728,
#  'mother': 729,
#  'county': 730,
#  'rules': 731,
#  'studies': 732,
#  'yet': 733,
#  'find': 734,
#  'knowledge': 735,
#  'put': 736,
#  'founded': 737,
#  'policy': 738,
#  'currently': 739,
#  'provide': 740,
#  'working': 741,
#  'media': 742,
#  'election': 743,
#  'australian': 744,
#  'me': 745,
#  'thomas': 746,
#  'allowed': 747,
#  'russia': 748,
#  'greater': 749,
#  'earlier': 750,
#  'limited': 751,
#  'object': 752,
#  'brought': 753,
#  'online': 754,
#  'lord': 755,
#  'association': 756,
#  'mostly': 757,
#  'blue': 758,
#  'across': 759,
#  'constitution': 760,
#  'added': 761,
#  'interest': 762,
#  'things': 763,
#  'relations': 764,
#  'speed': 765,
#  'federal': 766,
#  'singer': 767,
#  'effects': 768,
#  'growth': 769,
#  'sources': 770,
#  'your': 771,
#  'remains': 772,
#  'z': 773,
#  'gave': 774,
#  'probably': 775,
#  'simple': 776,
#  'attack': 777,
#  'longer': 778,
#  'reference': 779,
#  'saint': 780,
#  'success': 781,
#  'killed': 782,
#  'career': 783,
#  'past': 784,
#  'need': 785,
#  'park': 786,
#  'definition': 787,
#  'say': 788,
#  'etc': 789,
#  'peace': 790,
#  'give': 791,
#  'chief': 792,
#  'stories': 793,
#  'security': 794,
#  'wide': 795,
#  'ball': 796,
#  'saw': 797,
#  'machine': 798,
#  'better': 799,
#  'cell': 800,
#  'leading': 801,
#  'becomes': 802,
#  'larger': 803,
#  'spain': 804,
#  'night': 805,
#  'parties': 806,
#  'products': 807,
#  'remained': 808,
#  'prize': 809,
#  'big': 810,
#  'website': 811,
#  'months': 812,
#  'money': 813,
#  'cultural': 814,
#  'territory': 815,
#  'help': 816,
#  'moved': 817,
#  'private': 818,
#  'wife': 819,
#  'letter': 820,
#  'lines': 821,
#  'politics': 822,
#  'largely': 823,
#  'contains': 824,
#  'companies': 825,
#  'lake': 826,
#  'perhaps': 827,
#  'green': 828,
#  'already': 829,
#  'iii': 830,
#  'dead': 831,
#  'library': 832,
#  'separate': 833,
#  'refer': 834,
#  'makes': 835,
#  'appeared': 836,
#  'dutch': 837,
#  'holy': 838,
#  'era': 839,
#  'novel': 840,
#  'successful': 841,
#  'italy': 842,
#  'letters': 843,
#  'results': 844,
#  'matter': 845,
#  'produce': 846,
#  'origin': 847,
#  'claim': 848,
#  'whole': 849,
#  'attempt': 850,
#  'directly': 851,
#  'actress': 852,
#  'surface': 853,
#  'revolution': 854,
#  'highly': 855,
#  'caused': 856,
#  'status': 857,
#  'musical': 858,
#  'richard': 859,
#  'commercial': 860,
#  'division': 861,
#  'color': 862,
#  'release': 863,
#  'coast': 864,
#  'health': 865,
#  'latter': 866,
#  'authority': 867,
#  'treaty': 868,
#  'turn': 869,
#  'michael': 870,
#  'nation': 871,
#  'direct': 872,
#  'asia': 873,
#  'edition': 874,
#  'programming': 875,
#  'playing': 876,
#  'date': 877,
#  'whom': 878,
#  'native': 879,
#  'mary': 880,
#  'married': 881,
#  'towards': 882,
#  'issues': 883,
#  'double': 884,
#  'basis': 885,
#  'primary': 886,
#  'enough': 887,
#  'allow': 888,
#  'memory': 889,
#  'reason': 890,
#  'web': 891,
#  'exist': 892,
#  'provided': 893,
#  'functions': 894,
#  'course': 895,
#  'oil': 896,
#  'chemical': 897,
#  'analysis': 898,
#  'alexander': 899,
#  'replaced': 900,
#  'mid': 901,
#  'queen': 902,
#  'sun': 903,
#  'tv': 904,
#  'claims': 905,
#  'literature': 906,
#  'metal': 907,
#  'amount': 908,
#  'divided': 909,
#  'blood': 910,
#  'likely': 911,
#  'average': 912,
#  'access': 913,
#  'length': 914,
#  'smaller': 915,
#  'medical': 916,
#  'property': 917,
#  'students': 918,
#  'degree': 919,
#  'elections': 920,
#  'club': 921,
#  'claimed': 922,
#  'performance': 923,
#  'director': 924,
#  'digital': 925,
#  'museum': 926,
#  'front': 927,
#  'tradition': 928,
#  'difficult': 929,
#  'nearly': 930,
#  'schools': 931,
#  'washington': 932,
#  'gas': 933,
#  'map': 934,
#  'jesus': 935,
#  'rome': 936,
#  'louis': 937,
#  'unit': 938,
#  'baseball': 939,
#  'mind': 940,
#  'mark': 941,
#  'peter': 942,
#  'collection': 943,
#  'product': 944,
#  'congress': 945,
#  'programs': 946,
#  'changed': 947,
#  'ideas': 948,
#  'moon': 949,
#  'entire': 950,
#  'user': 951,
#  'ground': 952,
#  'records': 953,
#  'frequently': 954,
#  'increase': 955,
#  'highest': 956,
#  'finally': 957,
#  'sent': 958,
#  'board': 959,
#  'don': 960,
#  'notable': 961,
#  'methods': 962,
#  'read': 963,
#  'recently': 964,
#  'bit': 965,
#  'variety': 966,
#  'involved': 967,
#  'call': 968,
#  'democratic': 969,
#  'ten': 970,
#  'served': 971,
#  'minor': 972,
#  'hard': 973,
#  'objects': 974,
#  'birth': 975,
#  'increased': 976,
#  'nuclear': 977,
#  'section': 978,
#  'street': 979,
#  'windows': 980,
#  'relatively': 981,
#  'car': 982,
#  'move': 983,
#  'returned': 984,
#  'create': 985,
#  'bank': 986,
#  'conditions': 987,
#  'operation': 988,
#  'relationship': 989,
#  'adopted': 990,
#  'christ': 991,
#  'hall': 992,
#  'appear': 993,
#  'rest': 994,
#  'child': 995,
#  'element': 996,
#  'appears': 997,
#  'fall': 998,
#  'takes': 999,
#  ...}

# %% [markdown]
# #### Find word similarities

# %%
# explore embeddings
vector = w2v_model.wv['computer']  # get numpy vector of a word
print('The vector length of the word is {}.'.format(len(vector)))
# Out:
# The vector length of the word is 10.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Use the trained word2vec model to find most similar words for token _"computer"_.
# - 💻 **API:** You can use Gensim's `.most_similar` function.
#
# </div>

# %%
# print most similar words
similar_words = w2v_model.wv.most_similar('computer', topn=5)
print('The most similar words to "computer" are:')
for word, similarity in similar_words:
    print(f'{word}: {similarity:.4f}')
# Out:
# The most similar words to "computer" are:
# search: 0.9672
# digital: 0.9631
# hypercard: 0.9579
# desktop: 0.9572
# interactive: 0.9570

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Play around with initial settings
#
# - Re-train the model with different datasets ( [Wikipedia](https://radimrehurek.com/gensim/corpora/wikicorpus.html), [Opinosis](https://radimrehurek.com/gensim/corpora/opinosiscorpus.html) ) and vector sizes and run similarity with different top-n. How would you comment on the results?
# - Think about the limitations of the Word2vec approach.
#
# </div>

# %% [markdown]
# ***--- YOU CAN WRITE YOU ANSWER HERE ---***
#
# I changed the model to write-8 and it's much bigger vocabulary-wise, and the similarities between words seem to be much bigger on average. Changing the vector size from 100 to 10 made the probabilities bigger on average.

# %% [markdown]
# <a name="2"></a>
# ## 2. TASK B: Word embedding similarity
#
# For this task, we will use pre-trained word embedding models.
#
# **Word2Vec:** We will use once again Word2vec as in the previous question, but in this case we will load the pre-trained version of it that has been trained on a part of the Google News dataset (about 100 billion words). The model variant that we will use, contains 300-dimensional vectors for 3 million words and phrases.
#
# **GloVe:** We will also use GloVe word embeddings that have been pre-trained on 2B tweets, 27B tokens, 1.2M vocab, uncased. The model variant that we will use contains 100-dimensional vectors.
#
# Once we load the vector represenation of words, we will:
# - find similarities between group of words.
# - discover a very cool property of word embeddings through analogies.
# - evaluate their performance on how well they capture the semantics between words on the SimLex task.

# %% [markdown]
# ### 2.1 Using pre-trained word embedding models

# %%
# Show all available models in gensim-data
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
# Download the "word2vec-google-news-300" embeddings
w2v_vectors = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# Download the "glove-wiki-gigaword-100" embeddings
glove_vectors = gensim.downloader.load('glove-wiki-gigaword-100')
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# The best way to understand a data is by visualizing them. We will use t-SNE to reduce the data with 300 dimensions to 2 dimensions, so that we can plot the data on our screens.
# t-SNE is a non-linear dimensionality reduction algorithm that attempts to represent high-dimensional data and the underlying relationships between vectors in a lower-dimensional space.

# %%
# visualization utility function. NO NEED TO CHANGE ANYTHING HERE
sns.set_style('whitegrid')
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

def tsne_scatterplot(model, search_word, topn):
    labels = [search_word]
    tokens = [model[search_word]]
    similar = [1]
    close_words = model.similar_by_word(search_word, topn=topn)
    for word in close_words:
        tokens.append(model[word[0]])
        labels.append(word[0])
        similar.append(word[1])

    tsne_model = TSNE(n_components=2, perplexity=topn, init='pca')
    coordinates = tsne_model.fit_transform(np.array(tokens))
    df = pd.DataFrame({'x': [x for x in coordinates[:, 0]],
                       'y': [y for y in coordinates[:, 1]],
                       'words': labels,
                       'similarity': similar}
                      )
    fig, ax = plt.subplots()
    plot = ax.scatter(df.x, df.y, c=df.similarity, cmap='Reds')
    for i in range(len(df)):
        ax.annotate("  {} ({:.2f})".format(df.words[i].title(),
                                           df.similarity[i]),
                    (df.x[i], df.y[i]))

    plt.colorbar(mappable=plot, ax=ax)
    plt.title('t-SNE visualization for {}'.format(search_word))
    plt.show()

# %%
# visualize the most similar words for a given word.
tsne_scatterplot(glove_vectors, "computer", 20)

# %% [markdown]
# #### Interactive visualization
#
# In the following link, you can explore the state-of-the-art models in an interactive embedding visualization: https://projector.tensorflow.org/.
#
# Using the Embedding Projector, you can graphically represent high dimensional embeddings. This can be helpful in visualizing, examining, and understanding your embeddings.
#
# Give it a try! Test interesting clusters of similar words!

# %% [markdown]
# ### 2.2 Check word analogies
#
# The fact that we can analyze the use of words in language to deduce their meaning is a fundamental idea of [distributional semantics](https://en.wikipedia.org/wiki/Distributional_semantics). This is the inspiration behind many algorithms for learning numerical representations of words (word embeddings). An important aspect of these representations is the ability to solve word analogies of the form “A is to B what C is to X” using simple arithmetic. This is generally simplified as “King — Man + Woman $\sim$ Queen.
#
# In this subquestion we will explore interesting relations that can be extracted from word embeddings. You will be given semantic relations and you need to implement the respective code using the embedding model.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Use the pre-trained GloVe embeddings to implement the following analogies.
# - 💻 **API:** You can use Gensim's `.most_similar` function.
#
# </div>

# %% [markdown]
# **Analogy A:**  `King` — `Man` + `Woman` ~ `?`
#
# `?`: `Queen`

# %%
# Check the "most similar words", using the default "cosine similarity" measure.
similar_words = w2v_vectors.most_similar(positive=['king', 'woman'], negative=['man'])
for word, similarity in similar_words:
    print(f'{word}: {similarity:.4f}')
# Out:
# queen: 0.7118
# monarch: 0.6190
# princess: 0.5902
# crown_prince: 0.5499
# prince: 0.5377
# kings: 0.5237
# Queen_Consort: 0.5236
# queens: 0.5181
# sultan: 0.5099
# monarchy: 0.5087

# %% [markdown]
# **Analogy B:**  `France` — `Paris` + `Athens` ~ `?`
#
# `?`: `Greece`

# %%
# Check the "most similar words", using the default "cosine similarity" measure. 
similar_words = glove_vectors.most_similar(positive=['france', 'athens'], negative=['paris'])
for word, similarity in similar_words:
    print(f'{word}: {similarity:.4f}')
# Out:
# greece: 0.7968
# finland: 0.6546
# turkey: 0.6507
# bulgaria: 0.6442
# romania: 0.6315
# estonia: 0.6313
# portugal: 0.6254
# cyprus: 0.6252
# macedonia: 0.6197
# olympics: 0.6187

# %% [markdown]
# However, we should not forget that these models are trained in human generated language. Meaning that societal and demographic biases are inevitable. In the following example you will witness these kinds of biases in the final output.
#
# Fortunately, extensive research has been done to tackle this issue trying to de-bias the embeddings models. More regarding this topic will be covered in Week 10 when we will talk about Ethics in NLP regarding Toxicity, Bias and Fairness.
#
# **Analogy C:**  `Doctor` - `Man` + `Woman` ~ `Nurse`

# %%
# Check the "most similar words", using the default "cosine similarity" measure. 
similar_words = glove_vectors.most_similar(positive=['doctor', 'woman'], negative=['man'])
for word, similarity in similar_words:
    print(f'{word}: {similarity:.4f}')
# Out:
# nurse: 0.7735
# physician: 0.7189
# doctors: 0.6824
# patient: 0.6751
# dentist: 0.6726
# pregnant: 0.6642
# medical: 0.6520
# nursing: 0.6453
# mother: 0.6393
# hospital: 0.6387

# %% [markdown]
# ### 2.3 Evaluate different models with SimLex
#
# In this part of the exercise, we will evaluate the syntactic concreteness of the created vectors using their similarity. For this task, we will use the SimLex999 dataset which is a human-annotated dataset regarding the similarity of concepts of words.
#
# - 📄 Paper: https://aclanthology.org/J15-4004.pdf
# - 👾 More about the task: https://fh295.github.io/simlex.html
#
# > - Download the data from [here](https://fh295.github.io/SimLex-999.zip)
# > - Unzip the file and put the corresponding folder with the dataset in the same dir as this notebook
#
# SimLex-999 is a gold standard resource for the evaluation of models that learn the meaning of words and concepts. SimLex-999 provides a way of measuring how well models capture similarity, rather than relatedness or association.
#
# #### Dataset:
# SimLex-999.txt is a tab-separated plaintext file, where rows correspond to concept pairs and columns correspond to the properties of each pair.
#
# |Column | Description |
# |-------|:-------------|
# |word1| The first concept in the pair.|
# |word2| The second concept in the pair. Note that the order is only relevant to the column Assoc(USF). These values (free association scores) are asymmetric. All other values are symmetric properties independent of the ordering word1, word2.|
# |POS| The majority part-of-speech of the concept words, as determined by occurrence in the POS-tagged British National Corpus. Only pairs of matching POS are included in SimLex-999.|
# |SimLex999 | The SimLex999 similarity rating. Note that average annotator scores have been (linearly) mapped from the range [0,6] to the range [0,10] to match other datasets such as WordSim-353. |
# |conc(w1)| The concreteness rating of word1 on a scale of 1-7. Taken from the University of South Florida Free Association Norms database. |
# |conc(w2)| The concreteness rating of word2 on a scale of 1-7. Taken from the University of South Florida Free Association Norms database.|
# |concQ| The quartile the pair occupies based on the two concreteness ratings. Used for some analyses in the above paper.|
# |Assoc(USF)| The strength of free association from word1 to word2. Values are taken from the University of South Florida Free Association Dataset.|
# |SimAssoc333| Binary indicator of whether the pair is one of the 333 most associated in the dataset (according to Assoc(USF)). This subset of SimLex999 is often the hardest for computational models to capture because the noise from high association can confound the similarity rating. See the paper for more details.|
# |SD(SimLex)| The standard deviation of annotator scores when rating this pair. Low values indicate good agreement between the 15+ annotators on the similarity value SimLex999. Higher scores indicate less certainty. |

# %% [markdown]
# We will be using the **`SimLex999` similarity column** to evaluate our word embeddings on this dataset. We will select the top 50 most similar pairs according to simlex999 column which a score from 0 to 10 regarding the similarities of the two words (columns: word1, word2) and it has been annotated by humans. On this subset of data, we will find the similarity score of the two words using our two pre-trained embedding models (Word2Vec, GloVe).

# %%
# read data
simlex = pd.read_csv('SimLex-999/SimLex-999.txt', delimiter='\t')
simlex = simlex[['word1', 'word2', 'SimLex999']]
simlex.head()
# Out:
#    word1        word2  SimLex999
# 0    old          new       1.58
# 1  smart  intelligent       9.20
# 2   hard    difficult       8.77
# 3  happy     cheerful       9.55
# 4   hard         easy       0.95

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Print the min, avg and max values of SimLex999 score.
#
# </div>

# %%
# stats on the SimLex999 similarity score
print(f"Minimum SimLex999 similarity: {simlex['SimLex999'].min()}")
print(f"Maximum SimLex999 similarity: {simlex['SimLex999'].max()}")
print(f"Mean SimLex999 similarity: {simlex['SimLex999'].mean()}")
# Out:
# Minimum SimLex999 similarity: 0.23
# Maximum SimLex999 similarity: 9.8
# Mean SimLex999 similarity: 4.561571571571572

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Select the top 50 pairs with the highest SimLex similarity score.
# </div>

# %%
# select a subset of word-pairs with the highest similarity score given by annotators
simlex_similar_pairs = simlex.nlargest(50, 'SimLex999')[['word1', 'word2']]
print(simlex_similar_pairs)
# Out:
#            word1        word2
# 782       vanish    disappear
# 22         quick        rapid
# 205      creator        maker
# 8         stupid         dumb
# 16        insane        crazy
# 3          happy     cheerful
# 42         large          big
# 140          cow       cattle
# 18         large         huge
# 134         area       region
# 28        simple         easy
# 71       bizarre      strange
# 121      student        pupil
# 234     attorney       lawyer
# 781        occur       happen
# 162      hallway     corridor
# 128      teacher   instructor
# 799       inform       notify
# 1          smart  intelligent
# 34         weird          odd
# 143         taxi          cab
# 6          happy         glad
# 65        scarce         rare
# 529      drizzle         rain
# 786      protect       defend
# 298     boundary       border
# 784        plead          beg
# 885      declare     announce
# 165          cop      sheriff
# 442    adversary     opponent
# 25       strange          odd
# 236     business      company
# 352         pact    agreement
# 385  corporation     business
# 186      victory      triumph
# 59     essential    necessary
# 265    abundance       plenty
# 9          weird      strange
# 370    physician       doctor
# 592      journey         trip
# 129        movie         film
# 541         task          job
# 816       decide       choose
# 285        shore        coast
# 819         roam       wander
# 62       crucial    important
# 839      acquire          get
# 945  contemplate        think
# 120       friend        buddy
# 303      heroine         hero

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** For each word pair from `simlex_similar_pairs`, compute the similarity between the GloVe embeddings (also Word2Vec embeddings) of the words.
# - 💻 **API:** You can use Gensim's `.similarity` function.
#
# </div>

# %%
# computes the similarities of each pair using each word embedding model
def get_similarities(row, model):
    try:
        return model.similarity(row['word1'], row['word2'])
    except KeyError:
        return np.nan

similarities = simlex_similar_pairs.copy()
similarities['similarity_glove'] = similarities.apply(lambda row: get_similarities(row, glove_vectors), axis=1)
similarities['similarity_w2v'] = similarities.apply(lambda row: get_similarities(row, w2v_vectors), axis=1)

# Drop pairs if any word was missing from vocabulary
similarities = similarities.dropna()
similarities.head()
# Out:
#        word1      word2  similarity_glove  similarity_w2v
# 782   vanish  disappear          0.881494        0.900423
# 22     quick      rapid          0.561225        0.497791
# 205  creator      maker          0.243845        0.260506
# 8     stupid       dumb          0.836065        0.817314
# 16    insane      crazy          0.591737        0.733904

# %%
similarities.head()
# Out:
#        word1      word2  similarity_glove  similarity_w2v
# 782   vanish  disappear          0.881494        0.900423
# 22     quick      rapid          0.561225        0.497791
# 205  creator      maker          0.243845        0.260506
# 8     stupid       dumb          0.836065        0.817314
# 16    insane      crazy          0.591737        0.733904

# %%
# plots the distribution of similarity scores for each model
sims_w2v = similarities[['similarity_w2v']].rename(columns = {'similarity_w2v': 'similarity'})
sims_w2v['model'] = 'Word2vec'
sims_glove = similarities[['similarity_glove']].rename(columns = {'similarity_glove': 'similarity'})
sims_glove['model'] = 'GloVe'
to_plot = pd.concat([sims_w2v, sims_glove], ignore_index=True)
sns.displot(to_plot, x="similarity", hue="model", kind="kde")
plt.show()

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Extra quiz:
# Think about which model seems to perform better on these high-similarity examples and why based on your knowledge of how the embedding models have been trained.
#
# </div>

# %% [markdown]
# Word2Vec is better beacause it captures functional similarity it's trained on a much bigger dataset.

# %% [markdown]
# ----

# %% [markdown]
# <a id="3"></a>
# ## 3. TASK C: Sentiment analysis of movie reviews
#
# For this part, we will be using only the GloVe pre-trained embeddings.
#
# **Data:** We will build a sentiment classification model using the IMDB review dataset.
#
# > - Download the dataset [here](https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews?phase=FinishSSORegistration). You may have to sign in / sign up on Kaggle.
# > - Save the .csv file in the same dir as this notebook.
#
# The IMDB dataset has 50K movie reviews for natural language processing or Text analytics. This is a dataset for binary sentiment classification containing substantially more data than previous benchmark datasets. We provide a set of 25,000 highly polar movie reviews for training and 25,000 for testing.
#
# The goal is to predict if a review is positive or negative using a classification (potentiall deep learning) algorithm.
#
# For more dataset information, please go through the following link,
# http://ai.stanford.edu/~amaas/data/sentiment/

# %% [markdown]
# ![IMDB-reviews-dataset-stats.png](attachment:IMDB-reviews-dataset-stats.png)

# %% [markdown]
# ### 3.1 Dataset exploration

# %%
#read dataset
movie_reviews = pd.read_csv('IMDB Dataset.csv')
movie_reviews.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print('Number of movie reviews: {}'.format(len(movie_reviews)))
classes = movie_reviews['sentiment'].unique()
print('Number of classes: {} with values: {}'.format(len(classes), classes))
# Out:
# Number of movie reviews: 50000
# Number of classes: 2 with values: ['positive' 'negative']

# %%
# class distribution
positive = len(movie_reviews[movie_reviews['sentiment']=='positive'])
negative = len(movie_reviews[movie_reviews['sentiment']=='negative'])

print('# of positive samples: {}'.format(positive))
print('# of negative samples: {}'.format(negative))

sns.set_theme(rc={'figure.figsize':(5.7,5.27)})
sns.countplot(x=movie_reviews['sentiment'])
plt.show()
# Out:
# # of positive samples: 25000
# # of negative samples: 25000

# %% [markdown]
# ### 3.2 Data preprocessing
#
# To build our classifier, we will leverage the pre-trained word embeddings (GloVe). Going from word embeddings to sentence vectors, we will need to find a way to take into account the embeddings of all the words each review contains. We will apply 2 techniques to do so: average and max pooling.
#
# We will perform the following preprocessing steps:
# - Change the classes from str (negative, positive) to binary `(0, 1)`.
# - Get word embeddings and calculate the sentence vectors with both max and avg pooling.
# - Create a `pytorch.Dataset` instance of the IMDB data.

# %% [markdown]
# #### From class names to binary

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Change the classe names from str (negative, positive) to binary `(0, 1)` and add it as a new column to the exising dataframe.
#
# </div>

# %%
# classes to binary
movie_reviews['target'] = movie_reviews['sentiment'].apply(lambda x: 1 if x == 'positive' else 0)
movie_reviews.head()
# Out:
#                                               review sentiment  target
# 0  One of the other reviewers has mentioned that ...  positive       1
# 1  A wonderful little production. <br /><br />The...  positive       1
# 2  I thought this was a wonderful way to spend ti...  positive       1
# 3  Basically there's a family where a little boy ...  negative       0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive       1

# %% [markdown]
# #### From word embeddings to review embeddings

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** For each review in the dataset, calculate the review vector by pooling from the review's word embeddings. Implement both max and avg pooling.
# - 💻 **API:** You can use numpy functions to manipulate the arrays. For review tokenization you can use `gensim.utils.tokenize` function.
#
# </div>

# %%
# apply embedding model to the words of the reviews and then perform pooling
def pool_review(review, model, pooling_type='avg'):
    # use tokenize to handle punctuation and edge cases
    tokens = [word for word in tokenize(review.lower()) if word in model]
    
    if not tokens:
        # return a vector of zeros if no words are found in vocabulary
        return np.zeros(model.vector_size)
    
    vectors = [model[word] for word in tokens]
    
    if pooling_type == 'max':
        return np.max(vectors, axis=0)
    else:
        return np.mean(vectors, axis=0)

# using tqdm to track progress as this can take a minute
print("Calculating max pooling vectors...")
review_vectors_max = np.array([pool_review(r, glove_vectors, 'max') for r in tqdm(movie_reviews['review'])])

print("Calculating average pooling vectors...")
review_vectors_avg = np.array([pool_review(r, glove_vectors, 'avg') for r in tqdm(movie_reviews['review'])])
# Out:
# Calculating max pooling vectors...
# 100%|██████████| 50000/50000 [00:25<00:00, 1984.80it/s]
# Calculating max pooling vectors...
# 100%|██████████| 50000/50000 [00:25<00:00, 1984.80it/s]
# Calculating average pooling vectors...
# 100%|██████████| 50000/50000 [00:25<00:00, 1951.27it/s]
# 100%|██████████| 50000/50000 [00:25<00:00, 1951.27it/s]

# %% [markdown]
# #### PyTorch Dataset class for the imported data

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Create a PyTorch Dataset class with the input data. Instantiate this class with the input data.
# - 💻 **API:** You can use `torch.utils.data.Dataset` class.
#
# </div>

# %%
class IMDBreviews(Dataset):
    def __init__(self, review_vectors, targets):
        # Convert inputs to float32 and long (or float32 for binary targets) tensors
        self.x = torch.from_numpy(review_vectors).float()
        self.y = torch.tensor(targets.values).float()
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

dataset = IMDBreviews(review_vectors_avg, movie_reviews['target'])

# %%
# print tensors for sanity check
print('Total samples {} with sentence embedding size: {}'.format(dataset.x.shape[0], dataset.x.shape[1]))
# Out:
# Total samples 50000 with sentence embedding size: 100

# %% [markdown]
# #### Splitting dataset to train and test subsets

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Split the dataset into train and test sets (80-20% splits).
# - 💻 **API:** You can use `torch.utils.data.random_split` function.
#
# </div>

# %%
# split to train and test sets
train, test = torch.utils.data.random_split(dataset, [int(0.8 * len(dataset)), int(0.2 * len(dataset))], generator=torch.Generator().manual_seed(42))

# %%
print('Train size: {}'.format(len(train)))
print('Test size: {}'.format(len(test)))
# Out:
# Train size: 40000
# Test size: 10000

# %% [markdown]
# ### 3.3 Train & evaluate a classifier on the movie reviews
#
# Once we have preprocessed the data, we will create the training and evaluation pipelines.

# %% [markdown]
# #### PyTorch Module class for model setup

# %% [markdown]
# # create a pytorch nn.Module class for the simple logistic regression model
# class SentimentAnalysisModel(nn.Module):
#
#     def __init__(self, input_size):
#         super(SentimentAnalysisModel, self).__init__()
#         # Handle case where input_size is a Tensor (like dataset.x) or an int
#         in_features = input_size if isinstance(input_size, int) else input_size.shape[1]
#         self.linear = nn.Linear(in_features, 1)
#         self.sigmoid = nn.Sigmoid()
#
#     def forward(self, x):
#         return self.sigmoid(self.linear(x)).squeeze()

# %%
# create a pytorch nn.Module class for the simple logistic regression model (now changed to be a bit more complex with a hidden layer and non-linearity)
class SentimentAnalysisModel(nn.Module):
    def __init__(self, input_size, hidden_dim=64):
        super(SentimentAnalysisModel, self).__init__()
        in_features = input_size if isinstance(input_size, int) else input_size.shape[1]
        
        # Define a sequence of layers
        self.network = nn.Sequential(
            nn.Linear(in_features, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x).squeeze()

# %%
model = SentimentAnalysisModel(dataset.x)
model
# Out:
# SentimentAnalysisModel(
#   (network): Sequential(
#     (0): Linear(in_features=100, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 6,529 trainable parameters

# %% [markdown]
# #### Pytorch Data loader class for dataset batching

# %%
# create data loader
BATCH_SIZE = 128
train_loader = DataLoader(train, batch_size=BATCH_SIZE, shuffle=True)
test_loader= DataLoader(test, batch_size=BATCH_SIZE)

# %% [markdown]
# #### Training the model

# %%
# Construct a loss function and an optimizer. The call to model.parameters()
# in the SGD constructor will contain the learnable parameters of the two
# nn.Linear modules which are members of the model.
from torch import optim
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=1e-1)

# %% [markdown]
# # Training loop
# model.train()
# for epoch in range(10):
#     epoch_loss = 0
#     for i, data in enumerate(train_loader, 0):
#         # get the inputs
#         inputs, labels = data
#
#         # zero the gradients
#         optimizer.zero_grad()
#
#         # Forward pass: Compute predicted y by passing x to the model
#         y = model(inputs)
#
#         # Compute loss
#         loss = criterion(y, labels)
#
#         # Perform a backward pass, and update the weights.
#         loss.backward()
#         optimizer.step()
#
#         epoch_loss += loss.item()
#
#     print(f'Epoch {epoch + 1} | Loss: {(epoch_loss / len(train_loader)):.4f}')

# %%
# Training loop
model.train()
for epoch in range(10):
    epoch_loss = 0
    for i, data in enumerate(train_loader, 0):
        # get the inputs
        inputs, labels = data
        
        # zero the gradients
        optimizer.zero_grad()
        
        # Forward pass: Compute predicted y by passing x to the model
        y = model(inputs)
        
        # Compute loss
        loss = criterion(y, labels)
        
        # Perform a backward pass, and update the weights.
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        
    print(f'Epoch {epoch + 1} | Loss: {(epoch_loss / len(train_loader)):.4f}')
# Out:
# Epoch 1 | Loss: 0.6878
# Epoch 2 | Loss: 0.6604
# Epoch 3 | Loss: 0.6126
# Epoch 4 | Loss: 0.5944
# Epoch 5 | Loss: 0.5777
# Epoch 6 | Loss: 0.5657
# Epoch 7 | Loss: 0.5543
# Epoch 8 | Loss: 0.5376
# Epoch 9 | Loss: 0.5288
# Epoch 10 | Loss: 0.5248

# %% [markdown]
# # Evaluation on test set
# batch_loss = 0
# accuracy_metric = BinaryAccuracy()
# batch_acc = 0
#
# model.eval()
# with torch.no_grad():
#     for inputs, targets in test_loader:
#         # Forward pass
#         outputs = model(inputs)
#
#         # Compute loss
#         loss = criterion(outputs, targets)
#         batch_loss += loss.item()
#
#         # Compute accuracy
#         acc = accuracy_metric(outputs, targets)
#         batch_acc += acc.item()
#
# test_loss = batch_loss / len(test_loader)
# test_acc = batch_acc / len(test_loader)
#
# print(f'Test Loss: {test_loss:.4f}')
# print(f'Test Acc: {test_acc*100:.2f}%')

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Evaluate your model on the test set: for each batch of data, do the forward pass and compute the loss and the accuracy score.
# - 💻 **API:** Check the official API for the [testing process](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#test-the-network-on-the-test-data).
#
# </div>

# %%
batch_loss = 0
batch_acc = 0
# Instantiate accuracy once
accuracy_metric = BinaryAccuracy()

model.eval()
with torch.no_grad(): # Use torch.no_grad() for inference
    for data in test_loader:
        # get the inputs
        inputs, labels = data
        
        # run forward pass
        y = model(inputs)
        
        # Compute loss
        test_loss = criterion(y, labels)
        
        # Compute accuracy using the instance
        acc = accuracy_metric(y, labels)
        
        batch_loss += test_loss.item()
        batch_acc += acc.item()

test_loss = batch_loss / len(test_loader)
test_acc = batch_acc / len(test_loader)

print(f'Test Loss: {test_loss:.4f}')
print(f'Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.5130
# Test Acc: 74.29%

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Extra quiz:
# Play around with different settings (e.g. learning rate, batch size, epochs) and different architectures. Additionally try different pooling methods. Think how your design choices affect model performance on both train and test sets.
#
# </div>

# %% [markdown]
# Bigger batch size decrases both training and test loss. More complex architectures seem to increase both training and test loss.

# %% [markdown]
# ### 🎉 Congrats! You finished your first exercise session!
#
# Awesome work!
